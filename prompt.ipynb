# %% [markdown]
# **LangChain Components**
# 1. Models
# 2. Prompts
# 3. Chains
# 4. Memory
# 5. Indexes
# 6. Agents

# %% [markdown]
# Why use prompt template over f"" string. <br>
# - Default validation
# - Reusable
# - LangChain Ecosystem

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

template = PromptTemplate(
    template="""
    Write 6 lines poem on {topic}
""",
validate_template=True,
input_variables=['topic']
)

# %%
prompt = template.invoke('Lily')

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="llama3:8b",
    temperature=0,
)

# %%
print(llm.invoke(prompt).content)
# Out:
# Here is a 6-line poem about Lily:
#
# Lily's petals soft and pale,
# Unfurling beauty, without fail.
# In gardens she blooms with glee,
# A symbol of innocence, for you and me.
# Her sweet fragrance fills the air,
# Fragrant as her gentle care.
